-- %% [markdown]
-- # [dbo].[__MigrationHistory]

-- %%
USE [NewsPortalDb]
GO

-- %%
/****** Object:  Table [dbo].[__MigrationHistory]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__MigrationHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ContextKey] [nvarchar](300) NOT NULL,
	[Model] [varbinary](max) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK_dbo.__MigrationHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC,
	[ContextKey] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsCasts]

-- %%
/****** Object:  Table [dbo].[NewsCasts]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsCasts](
	[NewsCastId] [int] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](max) NOT NULL,
	[Text] [nvarchar](max) NOT NULL,
	[MultimediaUrl] [nvarchar](max) NULL,
	[NewsDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[NewsSourceId] [int] NOT NULL,
	[NewsCategoryId] [int] NOT NULL,
 CONSTRAINT [PK_dbo.NewsCasts] PRIMARY KEY CLUSTERED 
(
	[NewsCastId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsCategories]

-- %%
/****** Object:  Table [dbo].[NewsCategories]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsCategories](
	[NewsCategoryId] [int] IDENTITY(1,1) NOT NULL,
	[Category] [nvarchar](max) NOT NULL,
	[DateCategory] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
 CONSTRAINT [PK_dbo.NewsCategories] PRIMARY KEY CLUSTERED 
(
	[NewsCategoryId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsComments]

-- %%
/****** Object:  Table [dbo].[NewsComments]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsComments](
	[NewsCommentId] [int] IDENTITY(1,1) NOT NULL,
	[Comment] [nvarchar](max) NOT NULL,
	[CommentDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[UserId] [int] NOT NULL,
	[NewsCastId] [int] NOT NULL,
 CONSTRAINT [PK_dbo.NewsComments] PRIMARY KEY CLUSTERED 
(
	[NewsCommentId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsFavs]

-- %%
/****** Object:  Table [dbo].[NewsFavs]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsFavs](
	[NewsFavId] [int] IDENTITY(1,1) NOT NULL,
	[Fav] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[UserId] [int] NOT NULL,
	[NewsCastId] [int] NOT NULL,
 CONSTRAINT [PK_dbo.NewsFavs] PRIMARY KEY CLUSTERED 
(
	[NewsFavId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsShares]

-- %%
/****** Object:  Table [dbo].[NewsShares]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsShares](
	[NewsShareId] [int] IDENTITY(1,1) NOT NULL,
	[ShareDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[UserId] [int] NOT NULL,
	[NewsCastId] [int] NOT NULL,
	[SendUserId] [int] NOT NULL,
 CONSTRAINT [PK_dbo.NewsShares] PRIMARY KEY CLUSTERED 
(
	[NewsShareId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsSources]

-- %%
/****** Object:  Table [dbo].[NewsSources]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsSources](
	[NewsSourceId] [int] IDENTITY(1,1) NOT NULL,
	[CorpationName] [nvarchar](max) NOT NULL,
	[CorpationPassword] [nvarchar](max) NULL,
	[SourceDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
 CONSTRAINT [PK_dbo.NewsSources] PRIMARY KEY CLUSTERED 
(
	[NewsSourceId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NewsSubscribers]

-- %%
/****** Object:  Table [dbo].[NewsSubscribers]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NewsSubscribers](
	[NewsSubscriberId] [int] IDENTITY(1,1) NOT NULL,
	[DateSubscriber] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[UserId] [int] NOT NULL,
	[NewsSourceId] [int] NOT NULL,
 CONSTRAINT [PK_dbo.NewsSubscribers] PRIMARY KEY CLUSTERED 
(
	[NewsSubscriberId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 19.06.2023 23:41:22 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[UserId] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](max) NOT NULL,
	[Surname] [nvarchar](max) NOT NULL,
	[Age] [int] NOT NULL,
	[Email] [nvarchar](max) NOT NULL,
	[Password] [nvarchar](max) NOT NULL,
	[Gender] [int] NOT NULL,
	[ImageUrl] [nvarchar](max) NULL,
	[RegisterDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
 CONSTRAINT [PK_dbo.Users] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__NewsShare__SendU__6D0D32F4]

-- %%
ALTER TABLE [dbo].[NewsShares] ADD  DEFAULT ((0)) FOR [SendUserId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsCasts_dbo.NewsCategories_NewsCategoryId]

-- %%
ALTER TABLE [dbo].[NewsCasts]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsCasts_dbo.NewsCategories_NewsCategoryId] FOREIGN KEY([NewsCategoryId])
REFERENCES [dbo].[NewsCategories] ([NewsCategoryId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsCasts] CHECK CONSTRAINT [FK_dbo.NewsCasts_dbo.NewsCategories_NewsCategoryId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsCasts_dbo.NewsSources_NewsSourceId]

-- %%
ALTER TABLE [dbo].[NewsCasts]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsCasts_dbo.NewsSources_NewsSourceId] FOREIGN KEY([NewsSourceId])
REFERENCES [dbo].[NewsSources] ([NewsSourceId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsCasts] CHECK CONSTRAINT [FK_dbo.NewsCasts_dbo.NewsSources_NewsSourceId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsComments_dbo.NewsCasts_NewsCastId]

-- %%
ALTER TABLE [dbo].[NewsComments]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsComments_dbo.NewsCasts_NewsCastId] FOREIGN KEY([NewsCastId])
REFERENCES [dbo].[NewsCasts] ([NewsCastId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsComments] CHECK CONSTRAINT [FK_dbo.NewsComments_dbo.NewsCasts_NewsCastId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsComments_dbo.Users_UserId]

-- %%
ALTER TABLE [dbo].[NewsComments]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsComments_dbo.Users_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([UserId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsComments] CHECK CONSTRAINT [FK_dbo.NewsComments_dbo.Users_UserId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsFavs_dbo.NewsCasts_NewsCastId]

-- %%
ALTER TABLE [dbo].[NewsFavs]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsFavs_dbo.NewsCasts_NewsCastId] FOREIGN KEY([NewsCastId])
REFERENCES [dbo].[NewsCasts] ([NewsCastId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsFavs] CHECK CONSTRAINT [FK_dbo.NewsFavs_dbo.NewsCasts_NewsCastId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsFavs_dbo.Users_UserId]

-- %%
ALTER TABLE [dbo].[NewsFavs]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsFavs_dbo.Users_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([UserId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsFavs] CHECK CONSTRAINT [FK_dbo.NewsFavs_dbo.Users_UserId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsShares_dbo.NewsCasts_NewsCastId]

-- %%
ALTER TABLE [dbo].[NewsShares]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsShares_dbo.NewsCasts_NewsCastId] FOREIGN KEY([NewsCastId])
REFERENCES [dbo].[NewsCasts] ([NewsCastId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsShares] CHECK CONSTRAINT [FK_dbo.NewsShares_dbo.NewsCasts_NewsCastId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsShares_dbo.Users_UserId]

-- %%
ALTER TABLE [dbo].[NewsShares]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsShares_dbo.Users_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([UserId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsShares] CHECK CONSTRAINT [FK_dbo.NewsShares_dbo.Users_UserId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsSubscribers_dbo.NewsSources_NewsSourceId]

-- %%
ALTER TABLE [dbo].[NewsSubscribers]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsSubscribers_dbo.NewsSources_NewsSourceId] FOREIGN KEY([NewsSourceId])
REFERENCES [dbo].[NewsSources] ([NewsSourceId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsSubscribers] CHECK CONSTRAINT [FK_dbo.NewsSubscribers_dbo.NewsSources_NewsSourceId]
GO

-- %% [markdown]
-- # [FK_dbo.NewsSubscribers_dbo.Users_UserId]

-- %%
ALTER TABLE [dbo].[NewsSubscribers]  WITH CHECK ADD  CONSTRAINT [FK_dbo.NewsSubscribers_dbo.Users_UserId] FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([UserId])
ON DELETE CASCADE
GO
ALTER TABLE [dbo].[NewsSubscribers] CHECK CONSTRAINT [FK_dbo.NewsSubscribers_dbo.Users_UserId]
GO
